# %% [markdown]
# **Live Coding Notebook for Assignment 1**

# %% [markdown]
# *Days 1 & 2*

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
# make some sample data for plotting
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100,50)

# %%
# make a basic scatterplot
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y)

# %%
# create a bar plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x,y) # chahge to 'ax.barh' for horisontal bars
# Out:
# <BarContainer object of 50 artists>

# %%
# make a line plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

# %%
# make a histogram
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
# Add axis labels and titles
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()

# %%
# Modify labels and titles
# Make a dictionary with the properties we want for our labels
font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}

# Add fontdict arguments to our previous lineplot
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1)
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %%
# Move the lables with the loc argument
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1, loc = 'left') #moved the title to the left
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %%
# Remake our basic scatterplot - add color and marker arguments (American spelling)
fig, ax = plt.subplots(figsize=(5, 4))
ax.scatter( x,
y,
marker='*', # NEW ADDITIONS
color = "indigo") # NEW ADDITIONS
fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_15152/566709660.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Adjust the style and width of the line connecting our points
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,
y,
marker='*',
color = 'indigo',
linestyle = '--', # NEW ADDITIONS
linewidth = 2) # NEW ADDITIONS
fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_15152/2303017762.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Color modification using hex codes
fig, ax = plt.subplots(figsize=(5, 3))
# color being the new addition
ax.plot(x,y,marker='*', color = '#7425b9', linestyle = '--', linewidth = 2)
fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_15152/3198338300.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,marker='*',
        markersize = 12, # NEW ADDITIONS
        color = '#7425b9',
        linestyle = '--',
        linewidth = 2,
        markeredgecolor = '#fa9359', # NEW ADDITIONS
        markerfacecolor = '#000000' ) # NEW ADDITIONS

ax.grid(axis = 'y')

# %%
# Building a bubble chart using gapminder package
import seaborn as sns
from gapminder import gapminder # data set

# data
data = gapminder.loc[gapminder.year == 2007]

# use the scatterplot function to build the bubble map
sns.scatterplot(data=data, x="gdpPercap", y="lifeExp", size="pop", legend=False, sizes=(20, 2000)).set_title('Test test')

# show the graph
plt.show()

# %% [markdown]
# *Day 3*<br>
#
# Making more modifications to our plots using Matplotlib, including:
# - Legends
# - Annotations (text, shapes, and labels)
# - Axis Labels
# - Styles

# %%
# loading our libraries and making some sample data

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)

# %%
# Plotting both y variables on the same axis and adding labels with the legend

fig, ax = plt.subplots(figsize=(10, 3))
ax.plot(x, y1, label = "Person 1")
ax.plot(x, y2, label = "Person 2")
ax.legend(loc = "lower right")
fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_2354/856502223.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Modifying our legend

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(x, y1, label = "Person 1")
ax.plot(x, y2, label = "Person 2")
ax.legend(loc='lower right',
        frameon = True, #add frame around the legend
        fontsize = 12, #change font size
        ncol = 2, #specify number of columns
        shadow = True )
fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_2354/1142964969.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Moving the legend outside of the plot area

'''
We can position the legend outside of our plot by
- Specifying legend location as before
- Specifying where we want to anchor that location on our figure using `bbox_to_anchor`
'''

fig, ax = plt.subplots(figsize=(10, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='upper left',
bbox_to_anchor =(1, 1))
fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_2354/3878028881.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Annotations with the text() function

# Putting our data into a scatter plot this time
fig, ax = plt.subplots(figsize=(10, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

# Use the text() function to specify coordinates and text
ax.text(10, 110, "This value is important!",
        ha='center', ##alignment of text
        color = 'red', ##modify font colour
        size = 20) ##modify font size
ax.grid()
fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_2354/694115244.py:15: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Positioning text annotations

# Start by making a simple, empty set of axes
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])

# Then we can position our annotation with reference to the data (like before), the axes,
# or the figure (referencing axis/figure dimensions)

ax.text(1, 5, ". Data:(1, 5)", transform=ax.transData )
ax.text(0.5, 0.1, ". Axes:(0.5, 0.1)", transform=ax.transAxes )
ax.text(0.2, 0.2, ". Figure:(0.2, 0.2)", transform=fig.transFigure )
# Out:
# Text(0.2, 0.2, '. Figure:(0.2, 0.2)')

# %%
# Annotating with arrows
# We can use the annotate() function to annotate with arrows and text (e.g. to focus at a specific point)
# We have to specify the location to point at and the location where we want our text

fig, ax = plt.subplots(figsize=(10, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.annotate('This is important!',
            xy=(10, 95), xytext=(20, 94),
            arrowprops = dict(arrowstyle = "wedge", facecolor = "hotpink")) # use color = "colorname" for the color fill
fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_2354/500331104.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
'''
Removing tick marks and labels

We can remove tick marks or labels from our axis like so:
- Use locator to remove ticks and labels
- Use formatter to remove only labels
'''

fig, ax = plt.subplots(figsize=(10, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
# Limiting tick marks
# We can also define a maximum number of ticks we want on our axis

fig, ax = plt.subplots(figsize=(10, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
# Tick mark intervals
# We can set tick marks at a particular interval (in this case, 5) using MultipleLocator

fig, ax = plt.subplots(figsize=(10, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %%
# Rotating axis labels
# To rotate axis labels and horizontal alignment, use xticks()

fig, ax = plt.subplots(figsize=(10, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xticks(rotation=45, ha='right', fontsize = 12, font = 'serif')
fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_2354/3403666255.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
'''
Activity: Modifying axis title fonts
Can you use what we did in a previous lesson to modify our x axis title?
We want a serif font with indigo colour, and for the axis title to be “Shiny New X Axis!”
Use plt.xlabel()
HINT: Recall fontdict
'''

fig, ax = plt.subplots(figsize=(10, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xlabel("Shiny New X Axis!", fontsize = 18, fontdict={'family': 'serif', 'color': 'indigo'})
plt.show()

# %%
# Styles are a convenient way to change many aesthetic dimensions of our plots at the same time
# To view available pre-made styles, use:
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# To use a style, just type the following before you make your figure:
plt.style.use('seaborn-v0_8-talk')

fig, ax = plt.subplots(figsize=(10, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='upper left', bbox_to_anchor =(1, 0.3))
fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_2354/4155322487.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Subplots

# Loading our libraries and generating some new sample data

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0, 75,50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2 = np.array([110, 180, 240, 99, 220])

# %%
# In past lessons, to define our figure and its one axes, we would type:
# fig, ax = plt.subplots(figsize=(5, 3))

# Now we want to have two plots next to each other, so we just have to define multiple axes and their relative positions:
fig,(ax1, ax2) = plt.subplots(
        ncols=2,
        nrows=1,
        figsize=(7, 3)
        )

# Then we can use our new figure, with its two axes, and define the types of viz that we want to see in each

ax1.scatter(x1,y1)
ax2.bar(x2,y2)
fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_2354/3430734149.py:15: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0, 75,50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2 = np.array([110, 180, 240, 99, 220])

plt.style.use('ggplot')

fig,(ax1, ax2) = plt.subplots(
        ncols=2,
        nrows=1,
        figsize=(10, 3)
        )

ax1.plot(x1,y1, linestyle = '--')
ax2.bar(x2,y2)
ax1.text(10, 80, "Some random title",
        ha='center', ##alignment of text
        color = 'blue', ##modify font colour
        size = 20) ##modify font sizefig.show()

ax2.text(3, 270, "Another random title",
        ha='center', ##alignment of text
        color = 'green', ##modify font colour
        size = 20) ##modify font sizefig.show()

ax1.annotate('Double bam!',
            xy=(30, 69), xytext=(20, 94), size = 18,
            arrowprops = dict(color = "blue"))

fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_2354/94001205.py:31: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Multiple viz on one axes object
# Super easy: just call multiple plot methods on the same axes

# first make our sample data
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])
# define our figure and axes (just one this time)
fig, ax = plt.subplots(figsize=(7, 3))
# now call both bar and plot elements to the same axes (ax)
ax.bar(x, y1,
color = "indigo")
ax.plot(x, y2,
color = "red")

# %%
# Add error information

# First, calculate standard deviation of our data
y2_sd = np.std(y2)
# Then plot our line as before
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")

# %%
'''
Then use errorbar() to add in our error line (standard deviation in this case, but could be whatever value you calculated)
- yerr specifies that we’re plotting vertical error bars
- fmt makes sure we’re not plotting the actual data points, only the error
'''
ax.errorbar(x, #our x values
        y2, #our y values
        yerr = y2_sd,
        fmt = "none")
fig.show()
# Out:
# /var/folders/6g/zpbgfkbn6l54k9rbsjjvvzlh0000gn/T/ipykernel_2354/1508663247.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Customizing errorbar appearance

fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")
ax.errorbar(x,
        y2,
        yerr = y2_sd,
        fmt = "none",
        ecolor= "indigo",
        elinewidth= 4,
        capsize = 6,
        capthick= 4 )
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# Errorevery

# If we don’t want to see error bars for every single point, we can specify intervals using errorevery
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")
ax.errorbar(x,
        y2,
        yerr = y2_sd,
        fmt = "none",
        ecolor = "indigo",
        elinewidth = 4,
        capsize = 6,
        capthick = 4,
        errorevery= 2 )
# Out:
# <ErrorbarContainer object of 3 artists>
